# %%
library(phangorn)
library(rgl)

chib_dist <- read.csv('chib_dist.csv',
                     header = T)
# head(chib_dist)

chib_dist <- as.dist(chib_dist[,-1]) # In das "dist"-Format umwandeln
# chib_dist

# %%
nnet <- neighborNet(chib_dist, ord=NULL)
plot(nnet, "2D", cex=0.8) # sieht manchmal komisch aus (siehe "Note"). In dem Fall einfach nochmal plotten bis es passt oder 3D betrachten.

# plot(nnet, "3D", cex=0.8)
# Out:
# plot without title
